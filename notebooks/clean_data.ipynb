# %%
import pandas as pd

# %%
df = pd.read_excel('new_data.xlsx')

# %%
df
# Out:
#                                         Тип  Площадь, м2                  Дом  \
# 0    Посуточная аренда дома, дачи, коттеджа          170  1, Деревянный, 2021
# 1    Посуточная аренда дома, дачи, коттеджа          430                    4
# 2    Посуточная аренда дома, дачи, коттеджа          380                    2
# 3    Посуточная аренда дома, дачи, коттеджа          510                    3
# 4    Посуточная аренда дома, дачи, коттеджа          160                    2
# ..                                      ...          ...                  ...
# 195  Посуточная аренда дома, дачи, коттеджа          315                    2
# 196  Посуточная аренда дома, дачи, коттеджа          230   3, Кирпичный, 2014
# 197  Посуточная аренда дома, дачи, коттеджа           70   1, Каркасный, 2023
# 198  Посуточная аренда дома, дачи, коттеджа           85   1, Каркасный, 2022
# 199  Посуточная аренда дома, дачи, коттеджа           80   2, Каркасный, 2022
#
# ...

# %%
df['Цена'].iloc[0]
# Out:
# '33000 руб/день'

# %%
df = df.drop(columns=['Дом', 'Ремонт', 'Название коттеджного поселка', 'Отопление', 'Тип'])

# %%
df
# Out:
#      Площадь, м2  Количество спален     Участок  \
# 0            170                5.0   8.0, сот.
# 1            430                5.0  10.0, сот.
# 2            380                4.0  12.0, сот.
# 3            510                6.0  12.0, сот.
# 4            160                5.0  25.0, сот.
# ..           ...                ...         ...
# 195          315                4.0  15.0, сот.
# 196          230                5.0  10.0, сот.
# 197           70                2.0   7.0, сот.
# 198           85                3.0   7.0, сот.
# 199           80                2.0   2.0, сот.
#
#                                                  Адрес  \
# 0    Московская область, Домодедово городской округ...
# 1    Московская область, Мытищи городской округ, по...
# 2    Москва, д. Бачурино, 254, ш. Калужское (7 км д...
# 3    Московская область, Химки городской округ, Хим...
# 4    Московская область, Домодедово городской округ...
# ...

# %%
df.to_csv('data.csv', index = False)
